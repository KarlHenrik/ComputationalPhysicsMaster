# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
P = 5
centers = np.zeros((P, 2))
for i in range(P):
    centers[i] = np.random.rand(2)
    
n_P = 50
n = n_P * P
data = np.zeros((n, 2))
index = 0
for i in range(P):
    for j in range(n_P):
        data[index] = np.random.normal(loc=centers[i], scale=0.06, size=2)
        index += 1

# %%
data_home = np.zeros((n, 2))
data_home
for i in range(P):
    for j in range(n_P):
        if data_home[j, ]

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()
