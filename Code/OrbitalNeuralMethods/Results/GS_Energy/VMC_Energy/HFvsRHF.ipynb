# %%
hf = HF(system);
hf = compute_ground_state!(hf, max_iter = 1000, tol = 1e-10, verbose=0);

# %%
import Plots as plt
plt.pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
plt.bar(hf.C[:, 1], xlabel="Basis function ψᵢ", label="ϕ₁", title="Coefficients of the GHF orbitals")
plt.bar!(hf.C[:, 2], ylabel="Coefficient", label="ϕ₂")

# %%
rhf_sys = System(rhf)
Cr = rhf_sys.transform
plt.bar(Cr[:, 1], xlabel="Basis function ψᵢ", label="ϕ₁", title="Coefficients of the RHF orbitals")
plt.bar!(Cr[:, 2], ylabel="Coefficient", label="ϕ₂")

# %%
hf.C[:, 1]
# Out:
# 20-element Vector{Float64}:
#  -0.003560138574487956
#  -0.9654144745549376
#   0.0002497020980675018
#  -9.208211563981037e-7
#  -0.0009559077659505313
#  -0.2592166496555314
#   6.248056530344902e-7
#  -2.3040827061066594e-9
#   9.886002308364825e-5
#   0.0268081972775345
#   1.5001096621238675e-6
#  -5.5319227428143214e-9
#  -2.446720838556739e-5
#  -0.006634853288280728
#  -1.1019785071578665e-6
#   4.063742883641528e-9
#   8.456769597426112e-6
#   0.0022932499976682547
#   7.500604008274545e-7
#  -2.7659819117213616e-9

# %%
hf.C[:, 2]
# Out:
# 20-element Vector{Float64}:
#  -0.00030984073057786836
#   1.1425931203411496e-6
#   0.003664038076797944
#   0.9935892439722804
#  -0.00018697164781298045
#   6.894913981458221e-7
#   0.0004149338741149406
#   0.11251898196453905
#   1.022669282988159e-5
#  -3.771275917801824e-8
#  -3.679696931249468e-5
#  -0.009978355069840234
#  -3.8131231862039406e-6
#   1.406157387105857e-8
#   8.898987709992237e-6
#   0.002413167736158713
#   1.6474209566633313e-6
#  -6.075159484844474e-9
#  -3.2404179721076828e-6
#  -0.0008787147882843634
