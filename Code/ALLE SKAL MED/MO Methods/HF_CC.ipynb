# %%
using BenchmarkTools: @btime
import LinearAlgebra as la
using TensorOperations: @tensor

# %%
include("../Basis/basis.jl")
include("mo_methods.jl")

# %% [markdown]
# ## HO Basis and Spatial System

# %%
l = 20
ω = 0.25
basis = SpinBasis(HOBasis(l, ω))

n = 2
a = 0.25  # shielding term in coloumb interaction
grid = [x for x in range(-10, stop = 10, length = 2001)]
@time system = System(n, basis, grid, a);
# Out:
#   0.243955 seconds (3.41 k allocations: 48.067 MiB, 17.87% gc time)

# %% [markdown]
# ## CCSD

# %%
ccsd = setup_CCSD(system, α = 0.5);

# %%
for i in 1:10
    CCSD_Update!(ccsd);
end

# %%
energy(ccsd)

# %% [markdown]
# ## CCD

# %%
ccd = setup_CCD(system, α = 0.5);

# %%
@time CCD_Update!(ccd);

# %%
energy(ccd)

# %% [markdown]
# # HF

# %%
hf = setup_HF(system);

# %%
for i in 1:100
    HF_update!(hf);
end

# %%
energy(hf)
# Out:
# 0.8555020143902463

# %%
system = System(hf);

# %% [markdown]
# ## Pairing Basis and Pairing System

# %%
l = 8
g = 0.1
basis = Pairing(l, g)

n = 4
system = System(n, basis);
