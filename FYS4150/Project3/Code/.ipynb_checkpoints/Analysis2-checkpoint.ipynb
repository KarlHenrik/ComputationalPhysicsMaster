# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
nameMass = np.array(pd.read_csv("Output/test1.txt", header=None, delim_whitespace=True, nrows=1))[0]

df = pd.read_csv("Output/test1.txt", header=None, delim_whitespace=True, skiprows = 1)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.003798  0.007438  0.000023 -0.003054 -0.000728  0.000084 -0.170143
# 1    -0.003801  0.007437  0.000023 -0.003054 -0.000729  0.000084 -0.176440
# 2    -0.003804  0.007437  0.000023 -0.003053 -0.000730  0.000084 -0.182729
# 3    -0.003807  0.007436  0.000023 -0.003053 -0.000732  0.000084 -0.189011
# 4    -0.003810  0.007435  0.000023 -0.003053 -0.000733  0.000084 -0.195286
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.000601  0.000236  0.000038 -0.001097  0.001441  0.000016 -0.198388
# 9996  0.000600  0.000237  0.000038 -0.001098  0.001440  0.000016 -0.204642
# 9997  0.000599  0.000239  0.000038 -0.001099  0.001440  0.000016 -0.210888
# 9998  0.000597  0.000240  0.000038 -0.001100  0.001439  0.000016 -0.217125
# 9999  0.000596  0.000241  0.000038 -0.001100  0.001439  0.000016 -0.223353
#
#             7         8         9   ...        50        51        52  \
# 0     0.976558 -0.000018 -6.296616  ... -0.542877  0.239066  1.127756
# 1     0.975469 -0.000018 -6.293031  ... -0.542906  0.239044  1.127760
# 2     0.974340 -0.000018 -6.285732  ... -0.542934  0.239001  1.127770
# 3     0.973171 -0.000018 -6.278172  ... -0.542963  0.238958  1.127779
# 4     0.971961 -0.000018 -6.270353  ... -0.542992  0.238915  1.127788
# ...        ...       ...       ...  ...       ...       ...       ...
# 9995  0.963318 -0.000023 -6.258342  ... -0.784421 -0.199744  1.137112
# 9996  0.962023 -0.000023 -6.249952  ... -0.784440 -0.199787  1.137104
# 9997  0.960688 -0.000023 -6.241304  ... -0.784459 -0.199831  1.137096
# 9998  0.959314 -0.000023 -6.232397  ... -0.784478 -0.199875  1.137089
# 9999  0.957899 -0.000023 -6.223232  ... -0.784497 -0.199918  1.137081
#
#             53         54         55        56        57        58        59
# 0    -0.028828  12.972913 -31.362734 -0.396537  1.087204  0.196384 -0.330150
# 1    -0.028828  12.974000 -31.362537 -0.396868  1.087197  0.196400 -0.330150
# 2    -0.028827  12.975087 -31.362341 -0.397198  1.087184  0.196432 -0.330149
# 3    -0.028826  12.976174 -31.362145 -0.397528  1.087171  0.196463 -0.330149
# 4    -0.028825  12.977261 -31.361948 -0.397858  1.087158  0.196495 -0.330149
# ...        ...        ...        ...       ...       ...       ...       ...
# 9995 -0.018902  23.069239 -27.963415 -3.628070  0.923551  0.469025 -0.312215
# 9996 -0.018901  23.070163 -27.962946 -3.628382  0.923533  0.469048 -0.312212
# 9997 -0.018900  23.071086 -27.962477 -3.628694  0.923514  0.469071 -0.312209
# 9998 -0.018898  23.072010 -27.962008 -3.629006  0.923495  0.469094 -0.312206
# 9999 -0.018897  23.072933 -27.961539 -3.629319  0.923476  0.469117 -0.312203
#
# [10000 rows x 60 columns]

# %%
n_planets = len(nameMass) // 2
names = [nameMass[2*i] for i in range(n_planets)]
masses = [nameMass[2*i + 1] for i in range(n_planets)]

# %%
plt.figure(figsize=(8,8))
for i in range(n_planets):
    plt.plot(df[6*i], df[6*i + 1], label=names[i])
plt.show()
