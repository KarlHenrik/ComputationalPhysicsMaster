# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Output/ssys.txt", header=None, delim_whitespace=True)
df
# Out:
#                 0             1             2         3         4         5   \
# 0     0.000000e+00  0.000000e+00  0.000000e+00 -0.166346  0.969120 -0.000041
# 1     2.922391e-10 -1.270468e-09 -9.775846e-12 -0.172631  0.967992 -0.000041
# 2     8.770800e-10 -3.809795e-09 -2.936875e-11 -0.178909  0.966823 -0.000041
# 3     1.754870e-09 -7.616370e-09 -5.881875e-11 -0.185180  0.965614 -0.000041
# 4     2.925942e-09 -1.268859e-08 -9.816475e-11 -0.191443  0.964365 -0.000041
# ...            ...           ...           ...       ...       ...       ...
# 9995  2.994873e-02  2.562588e-03 -6.829646e-04 -0.204766  0.957210 -0.000742
# 9996  2.994959e-02  2.564808e-03 -6.829933e-04 -0.210958  0.955647 -0.000742
# 9997  2.995044e-02  2.567028e-03 -6.830221e-04 -0.217139  0.954044 -0.000742
# 9998  2.995129e-02  2.569248e-03 -6.830507e-04 -0.223310  0.952402 -0.000742
# 9999  2.995214e-02  2.571467e-03 -6.830794e-04 -0.229471  0.950720 -0.000741
#
# ...

# %%
plt.figure(figsize = (6, 6))
for i in range(3, 16, 3):
    x = np.array(df[i])
    y = np.array(df[i + 1])
    z = np.array(df[i + 2])
    plt.plot(x, y)
plt.show()
