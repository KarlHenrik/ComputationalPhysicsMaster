# %%
def orbitPlot(filename, title):
    nameMass = np.array(pd.read_csv(filename, header=None, delim_whitespace=True, nrows=1))[0]
    df = pd.read_csv(filename, header=None, delim_whitespace=True, skiprows = 1)
    
    plt.figure(figsize=(6, 6))
    plt.plot(df[6], df[7])
    plt.title(title)
    plt.xlabel("x (AU)")
    plt.ylabel("y (AU)")
    plt.show()

# %%
print(2)
# Out:
# 2

# %%
nameMass = np.array(pd.read_csv("Output/exponent2.000000.txt", header=None, delim_whitespace=True, nrows=1))[0]

df = pd.read_csv("Output/exponent2.000000.txt", header=None, delim_whitespace=True, skiprows = 1)

# %%
n_planets = len(nameMass) // 2
names = [nameMass[2*i] for i in range(n_planets)]
masses = [nameMass[2*i + 1] for i in range(n_planets)]

# %%
plt.figure(figsize=(8,8))
for i in range(n_planets):
    plt.plot(df[6*i], df[6*i + 1], label=names[i])
plt.show()
