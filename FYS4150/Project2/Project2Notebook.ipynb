# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#analytical - jacobi - arma
#csv_file = 'Results/analytical_eigvecs'
#csv_file = 'Results/arma_eigvecs'
csv_file = 'Results/E2jacobi_eigvecs'
df = pd.read_csv(csv_file, delim_whitespace=True, skiprows = 2, header=None)

eigvecs = np.array(df)

# %%
woC = eigvecs[:,0]**2

# %%
plt.plot(eigvecs[:,0]**2)
plt.plot(woC)
#plt.xlim(0,20)
plt.show()

# %%
plt.plot(eigvecs[:,0]**2)
plt.show()
